# %% [markdown]
# # Car Price Prediction using Feedforward Neural Network
# This notebook demonstrates the process of building a Feedforward Neural Network (FNN) to predict car prices using the provided dataset. We will go through data loading, cleaning, preprocessing, model building, training, evaluation, and prediction.

# %% [markdown]
# ## Data Loading
# We begin by loading the dataset using pandas.

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv("CarPrice_dataset.csv")
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Data Cleaning
# We check for missing values and drop unnecessary columns if any.

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %% [markdown]
# ## Data Preprocessing
# We handle categorical variables using one-hot encoding and normalize numerical features.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder,LabelEncoder
from sklearn.compose import ColumnTransformer

class ModifiedLabelEncoder(LabelEncoder):
  def fit_transform(self,y,*args,**kwargs):
    for i in y:
      y[i]= super().fit_transform(y[i]).reshape(-1,1)
    return y
  def transform(self,y,*args,**kwargs):
    for i in y:
      y[i]= super().transform(y[i]).reshape(-1,1)
    return y

# %%
# Separate features and target
X = df.drop(columns=['price'])
y = df['price']

# Identify categorical and numerical columns
#/categorical_cols = X.select_dtypes(include=['object']).columns.tolist()
#numerical_cols = X.select_dtypes(include=['int64', 'float64']).columns.tolist()
le=['CarName','carbody','drivewheel','enginetype','cylindernumber','fuelsystem']

ohe=[i for i in df.select_dtypes(include=['object']).columns if len(df[i].unique())==2]

num = df.select_dtypes([int,float]).columns.tolist()
num.pop()
transformer=ColumnTransformer(
    transformers=[
        ('num',StandardScaler(),num),
        ('ohe',OneHotEncoder(drop='first'),ohe),
        ('le',ModifiedLabelEncoder(),le)
    ],
    remainder='passthrough'
)
data=transformer.fit_transform(X)
X_train,X_test,y_train,y_test=train_test_split(data,y,test_size=0.2,random_state=42)
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Define preprocessing steps
#preprocessor = ColumnTransformer(
  #  transformers=[
   #     ('num', StandardScaler(), numerical_cols),
   #     ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_cols)
   # ])

# Apply preprocessing
#X_processed = preprocessor.fit_transform(X)

# Split the data
#X_train, X_test, y_train, y_test = train_test_split(X_processed, y, test_size=0.2, random_state=42)
# Out:
# ((164, 25), (41, 25), (164,), (41,))

# %% [markdown]
# ## Model Building
# We build a Feedforward Neural Network using TensorFlow/Keras.

# %%
X_train.shape
# Out:
# (164, 25)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

# Define the model
model = Sequential()
model.add(layers.Dense(256, activation='relu', input_shape=(X_train.shape[1],)))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(8, activation='relu'))
model.add(layers.Dense(1,activation='relu'))


# Compile the model
model.compile(optimizer='adam', loss='mean_absolute_error', metrics = ["mean_absolute_error", "mean_squared_error"])
model.summary()
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_69 (Dense)                │ (None, 256)            │         6,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_70 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_71 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_72 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_73 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_74 (Dense)                │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_75 (Dense)                │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 50,561 (197.50 KB)
#  Trainable params: 50,561 (197.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Model Training
# We train the model using the training data.

# %%
history = model.fit(X_train, y_train, epochs=130, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 397ms/step - loss: 12463.6094 - mean_absolute_error: 12463.6094 - mean_squared_error: 206057424.0000 - val_loss: 15068.7510 - val_mean_absolute_error: 15068.7510 - val_mean_squared_error: 317550720.0000
# Epoch 2/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 12716.9141 - mean_absolute_error: 12716.9141 - mean_squared_error: 216189632.0000 - val_loss: 15050.6113 - val_mean_absolute_error: 15050.6113 - val_mean_squared_error: 317049504.0000
# Epoch 3/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 12877.1133 - mean_absolute_error: 12877.1133 - mean_squared_error: 215124784.0000 - val_loss: 15016.8301 - val_mean_absolute_error: 15016.8301 - val_mean_squared_error: 316121536.0000
# Epoch 4/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 13023.9277 - mean_absolute_error: 13023.9277 - mean_squared_error: 220394848.0000 - val_loss: 14953.9463 - val_mean_absolute_error: 14953.9463 - val_mean_squared_error: 314399808.0000
# Epoch 5/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 12875.3047 - mean_absolute_error: 12875.3047 - mean_squared_error: 220678768.0000 - val_loss: 14837.6748 - val_mean_absolute_error: 14837.6748 - val_mean_squared_error: 311247200.0000
# Epoch 6/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 12733.0840 - mean_absolute_error: 12733.0840 - mean_squared_error: 216278336.0000 - val_loss: 14627.6641 - val_mean_absolute_error: 14627.6641 - val_mean_squared_error: 305637952.0000
# Epoch 7/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 12239.2217 - mean_absolute_error: 12239.2217 - mean_squared_error: 200942992.0000 - val_loss: 14255.4297 - val_mean_absolute_error: 14255.4297 - val_mean_squared_error: 295952704.0000
# Epoch 8/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 11573.7969 - mean_absolute_error: 11573.7969 - mean_squared_error: 179013248.0000 - val_loss: 13610.7939 - val_mean_absolute_error: 13610.7939 - val_mean_squared_error: 279942976.0000
# Epoch 9/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 10747.7412 - mean_absolute_error: 10747.7412 - mean_squared_error: 162147056.0000 - val_loss: 12534.0264 - val_mean_absolute_error: 12534.0264 - val_mean_squared_error: 255270032.0000
# Epoch 10/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 10260.9150 - mean_absolute_error: 10260.9150 - mean_squared_error: 157941248.0000 - val_loss: 10755.1543 - val_mean_absolute_error: 10755.1543 - val_mean_squared_error: 220567264.0000
# Epoch 11/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7796.3521 - mean_absolute_error: 7796.3521 - mean_squared_error: 111723440.0000 - val_loss: 8666.2109 - val_mean_absolute_error: 8666.2109 - val_mean_squared_error: 180487920.0000
# Epoch 12/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6087.3311 - mean_absolute_error: 6087.3311 - mean_squared_error: 80854360.0000 - val_loss: 8015.9072 - val_mean_absolute_error: 8015.9072 - val_mean_squared_error: 156157056.0000
# Epoch 13/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6983.3022 - mean_absolute_error: 6983.3022 - mean_squared_error: 98513864.0000 - val_loss: 8600.3135 - val_mean_absolute_error: 8600.3135 - val_mean_squared_error: 156125968.0000
# Epoch 14/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 7112.3638 - mean_absolute_error: 7112.3638 - mean_squared_error: 92782568.0000 - val_loss: 8144.6997 - val_mean_absolute_error: 8144.6997 - val_mean_squared_error: 151100064.0000
# Epoch 15/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6598.5347 - mean_absolute_error: 6598.5347 - mean_squared_error: 86638512.0000 - val_loss: 7765.5444 - val_mean_absolute_error: 7765.5444 - val_mean_squared_error: 153163376.0000
# Epoch 16/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6868.2285 - mean_absolute_error: 6868.2285 - mean_squared_error: 95348192.0000 - val_loss: 7813.8521 - val_mean_absolute_error: 7813.8521 - val_mean_squared_error: 156028976.0000
# Epoch 17/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5957.0674 - mean_absolute_error: 5957.0674 - mean_squared_error: 77697104.0000 - val_loss: 7685.3311 - val_mean_absolute_error: 7685.3311 - val_mean_squared_error: 152436304.0000
# Epoch 18/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5911.6729 - mean_absolute_error: 5911.6729 - mean_squared_error: 78781432.0000 - val_loss: 7517.5259 - val_mean_absolute_error: 7517.5259 - val_mean_squared_error: 147189120.0000
# Epoch 19/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5937.7349 - mean_absolute_error: 5937.7349 - mean_squared_error: 72931504.0000 - val_loss: 7358.4136 - val_mean_absolute_error: 7358.4136 - val_mean_squared_error: 139632096.0000
# Epoch 20/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6084.5078 - mean_absolute_error: 6084.5078 - mean_squared_error: 81242312.0000 - val_loss: 7274.2329 - val_mean_absolute_error: 7274.2329 - val_mean_squared_error: 135098704.0000
# Epoch 21/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5990.7090 - mean_absolute_error: 5990.7090 - mean_squared_error: 71204960.0000 - val_loss: 7160.1729 - val_mean_absolute_error: 7160.1729 - val_mean_squared_error: 131527664.0000
# Epoch 22/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5630.0083 - mean_absolute_error: 5630.0083 - mean_squared_error: 67027008.0000 - val_loss: 7042.5005 - val_mean_absolute_error: 7042.5005 - val_mean_squared_error: 133837952.0000
# Epoch 23/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5772.5400 - mean_absolute_error: 5772.5400 - mean_squared_error: 76789536.0000 - val_loss: 6965.4404 - val_mean_absolute_error: 6965.4404 - val_mean_squared_error: 132110944.0000
# Epoch 24/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5367.9326 - mean_absolute_error: 5367.9326 - mean_squared_error: 62713436.0000 - val_loss: 6796.6665 - val_mean_absolute_error: 6796.6665 - val_mean_squared_error: 126806184.0000
# Epoch 25/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5645.5752 - mean_absolute_error: 5645.5752 - mean_squared_error: 75532152.0000 - val_loss: 6674.2109 - val_mean_absolute_error: 6674.2109 - val_mean_squared_error: 123142664.0000
# Epoch 26/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4974.4834 - mean_absolute_error: 4974.4834 - mean_squared_error: 56424068.0000 - val_loss: 6524.7520 - val_mean_absolute_error: 6524.7520 - val_mean_squared_error: 115596952.0000
# Epoch 27/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5187.9448 - mean_absolute_error: 5187.9448 - mean_squared_error: 62559724.0000 - val_loss: 6359.9673 - val_mean_absolute_error: 6359.9673 - val_mean_squared_error: 111160680.0000
# Epoch 28/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4928.4199 - mean_absolute_error: 4928.4199 - mean_squared_error: 57679352.0000 - val_loss: 6249.4937 - val_mean_absolute_error: 6249.4937 - val_mean_squared_error: 110418240.0000
# Epoch 29/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5056.6489 - mean_absolute_error: 5056.6489 - mean_squared_error: 61742304.0000 - val_loss: 6071.2622 - val_mean_absolute_error: 6071.2622 - val_mean_squared_error: 105215704.0000
# Epoch 30/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4785.8389 - mean_absolute_error: 4785.8389 - mean_squared_error: 54492144.0000 - val_loss: 5862.7109 - val_mean_absolute_error: 5862.7109 - val_mean_squared_error: 97799136.0000
# Epoch 31/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4421.0225 - mean_absolute_error: 4421.0225 - mean_squared_error: 42762212.0000 - val_loss: 5697.7769 - val_mean_absolute_error: 5697.7769 - val_mean_squared_error: 92480912.0000
# Epoch 32/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4164.2378 - mean_absolute_error: 4164.2378 - mean_squared_error: 40013856.0000 - val_loss: 5530.9609 - val_mean_absolute_error: 5530.9609 - val_mean_squared_error: 86946528.0000
# Epoch 33/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4516.1562 - mean_absolute_error: 4516.1562 - mean_squared_error: 49318144.0000 - val_loss: 5329.8394 - val_mean_absolute_error: 5329.8394 - val_mean_squared_error: 82623720.0000
# Epoch 34/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3929.2986 - mean_absolute_error: 3929.2986 - mean_squared_error: 38862424.0000 - val_loss: 5198.0391 - val_mean_absolute_error: 5198.0391 - val_mean_squared_error: 76479408.0000
# Epoch 35/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3773.0898 - mean_absolute_error: 3773.0898 - mean_squared_error: 32952356.0000 - val_loss: 5289.1636 - val_mean_absolute_error: 5289.1636 - val_mean_squared_error: 69425728.0000
# Epoch 36/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3675.3904 - mean_absolute_error: 3675.3904 - mean_squared_error: 31002412.0000 - val_loss: 5075.2183 - val_mean_absolute_error: 5075.2183 - val_mean_squared_error: 64975132.0000
# Epoch 37/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3504.5601 - mean_absolute_error: 3504.5601 - mean_squared_error: 30870246.0000 - val_loss: 4821.5273 - val_mean_absolute_error: 4821.5273 - val_mean_squared_error: 61723916.0000
# Epoch 38/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3295.8506 - mean_absolute_error: 3295.8506 - mean_squared_error: 27233372.0000 - val_loss: 4650.1265 - val_mean_absolute_error: 4650.1265 - val_mean_squared_error: 57784292.0000
# Epoch 39/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2821.3730 - mean_absolute_error: 2821.3730 - mean_squared_error: 20002636.0000 - val_loss: 4632.6011 - val_mean_absolute_error: 4632.6011 - val_mean_squared_error: 51875208.0000
# Epoch 40/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2745.7632 - mean_absolute_error: 2745.7632 - mean_squared_error: 19921990.0000 - val_loss: 4437.6699 - val_mean_absolute_error: 4437.6699 - val_mean_squared_error: 48522316.0000
# Epoch 41/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2965.7566 - mean_absolute_error: 2965.7566 - mean_squared_error: 24561592.0000 - val_loss: 4370.4629 - val_mean_absolute_error: 4370.4629 - val_mean_squared_error: 44048952.0000
# Epoch 42/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3173.2969 - mean_absolute_error: 3173.2969 - mean_squared_error: 26369556.0000 - val_loss: 4288.6040 - val_mean_absolute_error: 4288.6040 - val_mean_squared_error: 41005032.0000
# Epoch 43/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2335.5081 - mean_absolute_error: 2335.5081 - mean_squared_error: 16115284.0000 - val_loss: 4120.8057 - val_mean_absolute_error: 4120.8057 - val_mean_squared_error: 40735804.0000
# Epoch 44/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2642.1479 - mean_absolute_error: 2642.1479 - mean_squared_error: 19978394.0000 - val_loss: 4123.8447 - val_mean_absolute_error: 4123.8447 - val_mean_squared_error: 40675396.0000
# Epoch 45/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2498.0769 - mean_absolute_error: 2498.0769 - mean_squared_error: 16523581.0000 - val_loss: 4050.7329 - val_mean_absolute_error: 4050.7329 - val_mean_squared_error: 38676780.0000
# Epoch 46/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2525.7380 - mean_absolute_error: 2525.7380 - mean_squared_error: 18432730.0000 - val_loss: 4071.3164 - val_mean_absolute_error: 4071.3164 - val_mean_squared_error: 37244788.0000
# Epoch 47/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2397.4316 - mean_absolute_error: 2397.4316 - mean_squared_error: 15206918.0000 - val_loss: 4198.2773 - val_mean_absolute_error: 4198.2773 - val_mean_squared_error: 36657380.0000
# Epoch 48/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2283.5139 - mean_absolute_error: 2283.5139 - mean_squared_error: 14655912.0000 - val_loss: 4000.3584 - val_mean_absolute_error: 4000.3584 - val_mean_squared_error: 39229320.0000
# Epoch 49/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2410.6772 - mean_absolute_error: 2410.6772 - mean_squared_error: 17650356.0000 - val_loss: 3974.9497 - val_mean_absolute_error: 3974.9497 - val_mean_squared_error: 38865160.0000
# Epoch 50/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2329.6853 - mean_absolute_error: 2329.6853 - mean_squared_error: 16456247.0000 - val_loss: 4098.6831 - val_mean_absolute_error: 4098.6831 - val_mean_squared_error: 35595400.0000
# Epoch 51/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2451.0803 - mean_absolute_error: 2451.0803 - mean_squared_error: 15684768.0000 - val_loss: 3875.9092 - val_mean_absolute_error: 3875.9092 - val_mean_squared_error: 35234444.0000
# Epoch 52/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2355.2878 - mean_absolute_error: 2355.2878 - mean_squared_error: 17406372.0000 - val_loss: 4092.7046 - val_mean_absolute_error: 4092.7046 - val_mean_squared_error: 40127872.0000
# Epoch 53/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2597.4849 - mean_absolute_error: 2597.4849 - mean_squared_error: 18200704.0000 - val_loss: 3941.7820 - val_mean_absolute_error: 3941.7820 - val_mean_squared_error: 37305396.0000
# Epoch 54/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2607.8430 - mean_absolute_error: 2607.8430 - mean_squared_error: 19611622.0000 - val_loss: 3773.1038 - val_mean_absolute_error: 3773.1038 - val_mean_squared_error: 33017378.0000
# Epoch 55/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2161.2625 - mean_absolute_error: 2161.2625 - mean_squared_error: 13595374.0000 - val_loss: 3743.3918 - val_mean_absolute_error: 3743.3918 - val_mean_squared_error: 32722886.0000
# Epoch 56/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 2400.9548 - mean_absolute_error: 2400.9548 - mean_squared_error: 16443593.0000 - val_loss: 3728.1133 - val_mean_absolute_error: 3728.1133 - val_mean_squared_error: 33022814.0000
# Epoch 57/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2335.3433 - mean_absolute_error: 2335.3433 - mean_squared_error: 16249732.0000 - val_loss: 3714.1841 - val_mean_absolute_error: 3714.1841 - val_mean_squared_error: 32750824.0000
# Epoch 58/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 2189.0491 - mean_absolute_error: 2189.0491 - mean_squared_error: 12882484.0000 - val_loss: 3783.0598 - val_mean_absolute_error: 3783.0598 - val_mean_squared_error: 31767908.0000
# Epoch 59/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2256.5901 - mean_absolute_error: 2256.5901 - mean_squared_error: 12863084.0000 - val_loss: 3671.9353 - val_mean_absolute_error: 3671.9353 - val_mean_squared_error: 31420956.0000
# Epoch 60/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2417.4453 - mean_absolute_error: 2417.4453 - mean_squared_error: 17086724.0000 - val_loss: 3657.8625 - val_mean_absolute_error: 3657.8625 - val_mean_squared_error: 31748102.0000
# Epoch 61/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 2133.7788 - mean_absolute_error: 2133.7788 - mean_squared_error: 13691828.0000 - val_loss: 3724.8174 - val_mean_absolute_error: 3724.8174 - val_mean_squared_error: 33234526.0000
# Epoch 62/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2473.1125 - mean_absolute_error: 2473.1125 - mean_squared_error: 18482528.0000 - val_loss: 3698.3228 - val_mean_absolute_error: 3698.3228 - val_mean_squared_error: 33872908.0000
# Epoch 63/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2300.2061 - mean_absolute_error: 2300.2061 - mean_squared_error: 16127926.0000 - val_loss: 3822.1399 - val_mean_absolute_error: 3822.1399 - val_mean_squared_error: 32910104.0000
# Epoch 64/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 2117.5234 - mean_absolute_error: 2117.5234 - mean_squared_error: 12363854.0000 - val_loss: 3709.4456 - val_mean_absolute_error: 3709.4456 - val_mean_squared_error: 34720424.0000
# Epoch 65/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2417.6848 - mean_absolute_error: 2417.6848 - mean_squared_error: 18404796.0000 - val_loss: 3708.6731 - val_mean_absolute_error: 3708.6731 - val_mean_squared_error: 34585300.0000
# Epoch 66/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2105.2874 - mean_absolute_error: 2105.2874 - mean_squared_error: 13453077.0000 - val_loss: 3705.5520 - val_mean_absolute_error: 3705.5520 - val_mean_squared_error: 33040608.0000
# Epoch 67/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2112.3374 - mean_absolute_error: 2112.3374 - mean_squared_error: 13867626.0000 - val_loss: 3710.0942 - val_mean_absolute_error: 3710.0942 - val_mean_squared_error: 32109754.0000
# Epoch 68/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2213.7449 - mean_absolute_error: 2213.7449 - mean_squared_error: 14038857.0000 - val_loss: 3675.1973 - val_mean_absolute_error: 3675.1973 - val_mean_squared_error: 32020684.0000
# Epoch 69/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2154.5562 - mean_absolute_error: 2154.5562 - mean_squared_error: 14777350.0000 - val_loss: 3635.7671 - val_mean_absolute_error: 3635.7671 - val_mean_squared_error: 32060210.0000
# Epoch 70/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1987.5570 - mean_absolute_error: 1987.5570 - mean_squared_error: 11674740.0000 - val_loss: 3658.3347 - val_mean_absolute_error: 3658.3347 - val_mean_squared_error: 33595648.0000
# Epoch 71/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 2174.9277 - mean_absolute_error: 2174.9277 - mean_squared_error: 15213646.0000 - val_loss: 3582.2087 - val_mean_absolute_error: 3582.2087 - val_mean_squared_error: 30642858.0000
# Epoch 72/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 2075.1416 - mean_absolute_error: 2075.1416 - mean_squared_error: 12193735.0000 - val_loss: 3600.6204 - val_mean_absolute_error: 3600.6204 - val_mean_squared_error: 29238678.0000
# Epoch 73/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 2066.9341 - mean_absolute_error: 2066.9341 - mean_squared_error: 11242024.0000 - val_loss: 3514.2847 - val_mean_absolute_error: 3514.2847 - val_mean_squared_error: 29443224.0000
# Epoch 74/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1990.7574 - mean_absolute_error: 1990.7574 - mean_squared_error: 11093667.0000 - val_loss: 3500.7966 - val_mean_absolute_error: 3500.7966 - val_mean_squared_error: 28499104.0000
# Epoch 75/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2009.5386 - mean_absolute_error: 2009.5386 - mean_squared_error: 11529220.0000 - val_loss: 3461.3574 - val_mean_absolute_error: 3461.3574 - val_mean_squared_error: 27043814.0000
# Epoch 76/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2092.8723 - mean_absolute_error: 2092.8723 - mean_squared_error: 12604844.0000 - val_loss: 3528.4368 - val_mean_absolute_error: 3528.4368 - val_mean_squared_error: 27944804.0000
# Epoch 77/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2042.7032 - mean_absolute_error: 2042.7032 - mean_squared_error: 12438503.0000 - val_loss: 3594.8926 - val_mean_absolute_error: 3594.8926 - val_mean_squared_error: 29810540.0000
# Epoch 78/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2019.8904 - mean_absolute_error: 2019.8904 - mean_squared_error: 10684436.0000 - val_loss: 3501.4966 - val_mean_absolute_error: 3501.4966 - val_mean_squared_error: 27279784.0000
# Epoch 79/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2443.7607 - mean_absolute_error: 2443.7607 - mean_squared_error: 16161930.0000 - val_loss: 3434.9639 - val_mean_absolute_error: 3434.9639 - val_mean_squared_error: 28682302.0000
# Epoch 80/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2055.5818 - mean_absolute_error: 2055.5818 - mean_squared_error: 12927757.0000 - val_loss: 3525.6199 - val_mean_absolute_error: 3525.6199 - val_mean_squared_error: 30427916.0000
# Epoch 81/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2348.5708 - mean_absolute_error: 2348.5708 - mean_squared_error: 16851300.0000 - val_loss: 3399.3672 - val_mean_absolute_error: 3399.3672 - val_mean_squared_error: 27798188.0000
# Epoch 82/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2403.0430 - mean_absolute_error: 2403.0430 - mean_squared_error: 17261162.0000 - val_loss: 3596.4358 - val_mean_absolute_error: 3596.4358 - val_mean_squared_error: 27175870.0000
# Epoch 83/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2176.9006 - mean_absolute_error: 2176.9006 - mean_squared_error: 11477324.0000 - val_loss: 3385.5818 - val_mean_absolute_error: 3385.5818 - val_mean_squared_error: 27844574.0000
# Epoch 84/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2093.5938 - mean_absolute_error: 2093.5938 - mean_squared_error: 14496778.0000 - val_loss: 3433.0483 - val_mean_absolute_error: 3433.0483 - val_mean_squared_error: 29180920.0000
# Epoch 85/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2071.8872 - mean_absolute_error: 2071.8872 - mean_squared_error: 13135420.0000 - val_loss: 3492.7375 - val_mean_absolute_error: 3492.7375 - val_mean_squared_error: 29994892.0000
# Epoch 86/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2283.7651 - mean_absolute_error: 2283.7651 - mean_squared_error: 15414191.0000 - val_loss: 3506.3362 - val_mean_absolute_error: 3506.3362 - val_mean_squared_error: 27286542.0000
# Epoch 87/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2373.2852 - mean_absolute_error: 2373.2852 - mean_squared_error: 15241948.0000 - val_loss: 3537.4495 - val_mean_absolute_error: 3537.4495 - val_mean_squared_error: 27036504.0000
# Epoch 88/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2143.3345 - mean_absolute_error: 2143.3345 - mean_squared_error: 11739594.0000 - val_loss: 3352.3125 - val_mean_absolute_error: 3352.3125 - val_mean_squared_error: 27295402.0000
# Epoch 89/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2000.1135 - mean_absolute_error: 2000.1135 - mean_squared_error: 12512598.0000 - val_loss: 3403.3618 - val_mean_absolute_error: 3403.3618 - val_mean_squared_error: 28291444.0000
# Epoch 90/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2104.9478 - mean_absolute_error: 2104.9478 - mean_squared_error: 12744385.0000 - val_loss: 3304.8794 - val_mean_absolute_error: 3304.8794 - val_mean_squared_error: 25728078.0000
# Epoch 91/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2224.9399 - mean_absolute_error: 2224.9399 - mean_squared_error: 14764154.0000 - val_loss: 3249.9966 - val_mean_absolute_error: 3249.9966 - val_mean_squared_error: 25457140.0000
# Epoch 92/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1933.5730 - mean_absolute_error: 1933.5730 - mean_squared_error: 11998893.0000 - val_loss: 3347.9177 - val_mean_absolute_error: 3347.9177 - val_mean_squared_error: 27040610.0000
# Epoch 93/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2088.0264 - mean_absolute_error: 2088.0264 - mean_squared_error: 13097175.0000 - val_loss: 3283.7405 - val_mean_absolute_error: 3283.7405 - val_mean_squared_error: 26111722.0000
# Epoch 94/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1849.2915 - mean_absolute_error: 1849.2915 - mean_squared_error: 9541118.0000 - val_loss: 3325.5422 - val_mean_absolute_error: 3325.5422 - val_mean_squared_error: 26187814.0000
# Epoch 95/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1951.4185 - mean_absolute_error: 1951.4185 - mean_squared_error: 11113110.0000 - val_loss: 3318.8345 - val_mean_absolute_error: 3318.8345 - val_mean_squared_error: 27345470.0000
# Epoch 96/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1826.7683 - mean_absolute_error: 1826.7683 - mean_squared_error: 10572063.0000 - val_loss: 3374.5066 - val_mean_absolute_error: 3374.5066 - val_mean_squared_error: 28770414.0000
# Epoch 97/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2051.3755 - mean_absolute_error: 2051.3755 - mean_squared_error: 14154566.0000 - val_loss: 3297.6951 - val_mean_absolute_error: 3297.6951 - val_mean_squared_error: 26325904.0000
# Epoch 98/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1797.1169 - mean_absolute_error: 1797.1169 - mean_squared_error: 10376304.0000 - val_loss: 3281.5166 - val_mean_absolute_error: 3281.5166 - val_mean_squared_error: 26076140.0000
# Epoch 99/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1986.8054 - mean_absolute_error: 1986.8054 - mean_squared_error: 11475426.0000 - val_loss: 3281.9758 - val_mean_absolute_error: 3281.9758 - val_mean_squared_error: 26038974.0000
# Epoch 100/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1930.6694 - mean_absolute_error: 1930.6694 - mean_squared_error: 11970394.0000 - val_loss: 3296.9968 - val_mean_absolute_error: 3296.9968 - val_mean_squared_error: 26927760.0000
# Epoch 101/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1812.1672 - mean_absolute_error: 1812.1672 - mean_squared_error: 9810386.0000 - val_loss: 3309.5349 - val_mean_absolute_error: 3309.5349 - val_mean_squared_error: 27368898.0000
# Epoch 102/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1968.4536 - mean_absolute_error: 1968.4536 - mean_squared_error: 13071620.0000 - val_loss: 3252.6377 - val_mean_absolute_error: 3252.6377 - val_mean_squared_error: 24940742.0000
# Epoch 103/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2158.4106 - mean_absolute_error: 2158.4106 - mean_squared_error: 13104400.0000 - val_loss: 3261.0554 - val_mean_absolute_error: 3261.0554 - val_mean_squared_error: 23626124.0000
# Epoch 104/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1920.7437 - mean_absolute_error: 1920.7437 - mean_squared_error: 10005798.0000 - val_loss: 3186.7388 - val_mean_absolute_error: 3186.7388 - val_mean_squared_error: 23122162.0000
# Epoch 105/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2047.7910 - mean_absolute_error: 2047.7910 - mean_squared_error: 11182932.0000 - val_loss: 3130.6941 - val_mean_absolute_error: 3130.6941 - val_mean_squared_error: 23353012.0000
# Epoch 106/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2031.2107 - mean_absolute_error: 2031.2107 - mean_squared_error: 13250257.0000 - val_loss: 3210.9688 - val_mean_absolute_error: 3210.9688 - val_mean_squared_error: 24168098.0000
# Epoch 107/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1885.3824 - mean_absolute_error: 1885.3824 - mean_squared_error: 10180845.0000 - val_loss: 3180.5864 - val_mean_absolute_error: 3180.5864 - val_mean_squared_error: 22850122.0000
# Epoch 108/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2096.9561 - mean_absolute_error: 2096.9561 - mean_squared_error: 12961632.0000 - val_loss: 3127.9731 - val_mean_absolute_error: 3127.9731 - val_mean_squared_error: 23128302.0000
# Epoch 109/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2066.5793 - mean_absolute_error: 2066.5793 - mean_squared_error: 12660604.0000 - val_loss: 3280.9492 - val_mean_absolute_error: 3280.9492 - val_mean_squared_error: 25005124.0000
# Epoch 110/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1975.5955 - mean_absolute_error: 1975.5955 - mean_squared_error: 10905637.0000 - val_loss: 3150.4104 - val_mean_absolute_error: 3150.4104 - val_mean_squared_error: 22948922.0000
# Epoch 111/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1920.6268 - mean_absolute_error: 1920.6268 - mean_squared_error: 10347632.0000 - val_loss: 3172.9780 - val_mean_absolute_error: 3172.9780 - val_mean_squared_error: 23047474.0000
# Epoch 112/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2055.3464 - mean_absolute_error: 2055.3464 - mean_squared_error: 12469678.0000 - val_loss: 3160.4043 - val_mean_absolute_error: 3160.4043 - val_mean_squared_error: 23453632.0000
# Epoch 113/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1911.5984 - mean_absolute_error: 1911.5984 - mean_squared_error: 10864924.0000 - val_loss: 3181.2188 - val_mean_absolute_error: 3181.2188 - val_mean_squared_error: 24367574.0000
# Epoch 114/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1903.2393 - mean_absolute_error: 1903.2393 - mean_squared_error: 10022656.0000 - val_loss: 3153.8765 - val_mean_absolute_error: 3153.8765 - val_mean_squared_error: 24258184.0000
# Epoch 115/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1920.2737 - mean_absolute_error: 1920.2737 - mean_squared_error: 10425187.0000 - val_loss: 3251.4541 - val_mean_absolute_error: 3251.4541 - val_mean_squared_error: 26368058.0000
# Epoch 116/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1936.5229 - mean_absolute_error: 1936.5229 - mean_squared_error: 11881797.0000 - val_loss: 3188.4260 - val_mean_absolute_error: 3188.4260 - val_mean_squared_error: 24347066.0000
# Epoch 117/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1845.5271 - mean_absolute_error: 1845.5271 - mean_squared_error: 9200850.0000 - val_loss: 3206.0232 - val_mean_absolute_error: 3206.0232 - val_mean_squared_error: 24048510.0000
# Epoch 118/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1918.0311 - mean_absolute_error: 1918.0311 - mean_squared_error: 10023336.0000 - val_loss: 3206.9592 - val_mean_absolute_error: 3206.9592 - val_mean_squared_error: 26182858.0000
# Epoch 119/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2203.0715 - mean_absolute_error: 2203.0715 - mean_squared_error: 15891788.0000 - val_loss: 3145.8171 - val_mean_absolute_error: 3145.8171 - val_mean_squared_error: 24332638.0000
# Epoch 120/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1836.8857 - mean_absolute_error: 1836.8857 - mean_squared_error: 11033427.0000 - val_loss: 3259.7812 - val_mean_absolute_error: 3259.7812 - val_mean_squared_error: 24049550.0000
# Epoch 121/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2113.9548 - mean_absolute_error: 2113.9548 - mean_squared_error: 11249572.0000 - val_loss: 3279.7524 - val_mean_absolute_error: 3279.7524 - val_mean_squared_error: 23613792.0000
# Epoch 122/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1812.5137 - mean_absolute_error: 1812.5137 - mean_squared_error: 8374785.0000 - val_loss: 3137.2500 - val_mean_absolute_error: 3137.2500 - val_mean_squared_error: 23799794.0000
# Epoch 123/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1871.3281 - mean_absolute_error: 1871.3281 - mean_squared_error: 9244615.0000 - val_loss: 3134.9014 - val_mean_absolute_error: 3134.9014 - val_mean_squared_error: 22955386.0000
# Epoch 124/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1909.5051 - mean_absolute_error: 1909.5051 - mean_squared_error: 11711932.0000 - val_loss: 3159.6113 - val_mean_absolute_error: 3159.6113 - val_mean_squared_error: 24630490.0000
# Epoch 125/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2035.1559 - mean_absolute_error: 2035.1559 - mean_squared_error: 12175032.0000 - val_loss: 3280.3584 - val_mean_absolute_error: 3280.3584 - val_mean_squared_error: 26438140.0000
# Epoch 126/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1928.9487 - mean_absolute_error: 1928.9487 - mean_squared_error: 11673312.0000 - val_loss: 3298.4783 - val_mean_absolute_error: 3298.4783 - val_mean_squared_error: 23151468.0000
# Epoch 127/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2205.5166 - mean_absolute_error: 2205.5166 - mean_squared_error: 12146950.0000 - val_loss: 3092.7827 - val_mean_absolute_error: 3092.7827 - val_mean_squared_error: 23086850.0000
# Epoch 128/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1831.5488 - mean_absolute_error: 1831.5488 - mean_squared_error: 10508405.0000 - val_loss: 3254.9641 - val_mean_absolute_error: 3254.9641 - val_mean_squared_error: 24761870.0000
# Epoch 129/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1930.3125 - mean_absolute_error: 1930.3125 - mean_squared_error: 11954495.0000 - val_loss: 3069.2949 - val_mean_absolute_error: 3069.2949 - val_mean_squared_error: 22336336.0000
# Epoch 130/130
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1819.1780 - mean_absolute_error: 1819.1780 - mean_squared_error: 8930026.0000 - val_loss: 3058.6033 - val_mean_absolute_error: 3058.6033 - val_mean_squared_error: 22653358.0000

# %% [markdown]
# ## Model Evaluation
# We evaluate the model using the test data.

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error, r2_score

y_pred = model.predict(X_test)

# Calculate metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error: {mae}")
print(f"Mean Squared Error: {mse}")
print(f"R-squared Score: {r2}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 263ms/step
# Mean Absolute Error: 2416.7369833269818
# Mean Squared Error: 14868305.128655318
# R-squared Score: 0.8116601490146977

# %% [markdown]
# ## Prediction on New Data
# We demonstrate prediction using new sample data.

# %%
# Example new data (replace with actual values from dataset)
new_data = X.iloc[[0]]
new_data_processed = preprocessor.transform(new_data)

predicted_price = model.predict(new_data_processed)
print(f"Predicted Price: {predicted_price[0][0]}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-848689328.py in <cell line: 0>()
#       1 # Example new data (replace with actual values from dataset)
#       2 new_data = X.iloc[[0]]
# ----> 3 new_data_processed = preprocessor.transform(new_data)
#       4
#       5 predicted_price = model.predict(new_data_processed)
#
# NameError: name 'preprocessor' is not defined
